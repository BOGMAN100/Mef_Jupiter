# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# будет 4 массива x1 y1 x2 y2 или типо тогояк

# %%
norm = np.random.normal(0, 1, [2, 1000])
# logNorm = np.random.lognormal(0, 1, [2, 1000])
# event = np.random.uniform(0, 1, [2, 1000])

print(f'normal : {norm} \n log normal: {logNorm} \n evently: {event}')
# Out:
# normal : [[ 1.22556747  0.44224518  1.06718854 ... -1.14628073  0.98215678
#    0.09142279]
#  [-0.2610133   2.00426921  0.59959526 ... -1.47580407  0.07137857
#    0.86140712]]
#  log normal: [[0.5945614  0.95599827 0.18230693 ... 0.59027834 1.12941608 0.83238925]
#  [0.09739207 1.4587303  0.17613477 ... 0.29005062 2.62821252 0.41113499]]
#  evently: [[0.25950394 0.17233321 0.56456079 ... 0.94733071 0.71606549 0.83536053]
#  [0.27442306 0.36022026 0.19643028 ... 0.34515486 0.0372576  0.34984951]]

# %%
# count, bins, ignored = plt.hist(norm, 15, density=True)
# plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')
# plt.plot(norm[1], norm[2])

plt.figure(1)
plt.scatter(norm[0], norm[1], color='red')
plt.title("Normal distribution")
# plt.show()

plt.figure(2)
plt.scatter(logNorm[0], logNorm[1], color='blue')
plt.title("Lognormal distribution")
# plt.show()


plt.figure(3)
plt.scatter(event[0], event[1], color='green')
plt.title("Evently distribution")
# plt.show()


plt.show()
